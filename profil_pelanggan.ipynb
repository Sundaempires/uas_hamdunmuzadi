# %% [markdown]
# <a href="https://colab.research.google.com/github/Sundaempires/uas_hamdunmuzadi/blob/main/profil_pelanggan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')

data_kode = data['kode']
data_prov = data['provinsi']

print(data_kode, data_prov)
# Out:
# 0       12461
# 1       12590
# 2       16839
# 3       13596
# 4       12395
#         ...
# 2353    18257
# 2354    12510
# 2355    16198
# 2356    16235
# 2357    15572
# Name: kode, Length: 2358, dtype: int64 0        Jawa Timur
# 1        Jawa Barat
# 2       DKI Jakarta
# 3       DKI Jakarta
# 4         Luar Jawa
#            ...
# 2353    DKI Jakarta
# 2354    Jawa Tengah
# 2355    DKI Jakarta
# 2356    DKI Jakarta
# 2357    DKI Jakarta
# Name: provinsi, Length: 2358, dtype: object

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')
data_kode = data['kode']
data_prov = data['provinsi']

plt.scatter(data_kode, data_prov)
plt.title('Scatter Plot')
plt.xlabel('Kode')
plt.ylabel('Provinsi')

plt.show()

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')

data_kode = data['kode']
data_prov = data['provinsi']

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(data_kode, data_prov, color='blue', alpha=0.7)

ax.set_title('Scatter Plot - Kode vs. Provinsi')
ax.set_xlabel('Kode')
ax.set_ylabel('Provinsi')

ax.tick_params(axis='x')

plt.show()

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')

data_kode = data['kode']
data_prov = data['provinsi']

fig, ax = plt.subplots(figsize=(12, 6))

ax.scatter(data_kode, data_prov, color='red', alpha=0.7, s=50)

ax.set_title('Scatter Plot - Kode vs. Provinsi')
ax.set_xlabel('Kode')
ax.set_ylabel('Provinsi')

ax.tick_params(axis='x', rotation=90)

plt.show()

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')

data_kode = data['kode']
data_prov = data['provinsi']

unique_provinces = data_prov.unique()
num_provinces = len(unique_provinces)
colors = plt.cm.get_cmap('Set3', num_provinces)
color_mapping = {province: colors(i) for i, province in enumerate(unique_provinces)}

fig, ax = plt.subplots(figsize=(12, 6))

for province in unique_provinces:
    province_data = data[data['provinsi'] == province]
    ax.scatter(province_data['kode'], province_data['provinsi'], color=color_mapping[province], alpha=0.7, label=province)

ax.set_title('Scatter Plot - Kode vs. Provinsi')
ax.set_xlabel('Kode')
ax.set_ylabel('Provinsi')

ax.tick_params(axis='x', rotation=90)

ax.legend()

plt.show()
# Out:
# <ipython-input-14-4a7a5ad43aec>:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('Set3', num_provinces)

# %%
data = pd.read_csv('/content/profile_pelanggan.csv')

data_kode = data['kode']
data_prov = data['provinsi']

unique_provinces = data_prov.unique()
num_provinces = len(unique_provinces)
colors = plt.cm.get_cmap('tab20', num_provinces)
color_mapping = {province: colors(i) for i, province in enumerate(unique_provinces)}

fig, ax = plt.subplots(figsize=(12, 6))

for province in unique_provinces:
    province_data = data[data['provinsi'] == province]
    ax.scatter(province_data['kode'], province_data['provinsi'], color=color_mapping[province], alpha=0.9, label=province)

ax.set_title('Scatter Plot - Kode vs. Provinsi')
ax.set_xlabel('Kode')
ax.set_ylabel('Provinsi')

ax.tick_params(axis='x', rotation=90)

ax.legend()

plt.show()
# Out:
# <ipython-input-17-accb25454f4f>:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20', num_provinces)
